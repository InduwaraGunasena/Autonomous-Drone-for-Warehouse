# %% [markdown]
# <a href="https://colab.research.google.com/github/InduwaraGunasena/Autonomous-Drone-for-Warehouse/blob/main/Data_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Processing**
#
# 1. Dataset loading: images and masks.
# 2. Dataset split:
#   * Training dataset
#   * Validation dataset
#   * Test dataset
# 3. Save the dataset

# %% [markdown]
# ## **Import Libraries**

# %%
import os
import numpy as np
import cv2
from glob import glob
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## **Dataset loading: images and masks**

# %%
def load_dataset(path):
  images = sorted(glob(os.path.join(path, "images", "*")))
  masks = sorted(glob(os.path.join(path, "masks", "*")))
  return images, masks

# %% [markdown]
# ## **Dataset split**

# %%
def split_dataset(images, masks, split=0.2):
  split_size = int(len(images) * split)

  train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
  train_y, valid_y = train_test_split(masks, test_size=split_size, random_state=42)

  train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
  train_y, test_y = train_test_split(train_y, test_size=split_size, random_state=42)

  return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %% [markdown]
# ## **Saving the dataset**
#
# ### **Creating a folder**

# %%
def create_dir(path):
  if not os.path.exists(path):
    os.makedirs(path)

# %%
def save_dataset(images, masks, save_dir):
  for x, y in tqdm(zip(images, masks), total=len(images)):
    name = x.split("/")[-1]  # take the image file name. (e.g. :- "1.jpg")

    x = cv2.imread(x, cv2.IMREAD_COLOR)
    y = cv2.imread(y, cv2.IMREAD_COLOR)

    save_image_path = os.path.join(save_dir, "images", name)
    save_mask_path = os.path.join(save_dir, "masks", name)

    cv2.imwrite(save_image_path, x)
    cv2.imwrite(save_mask_path, y)

# %% [markdown]
# ## **Executing the program**
#
# ### **Loading dataset**

# %%
dataset_path = "/content/drive/MyDrive/Colab Notebooks/data"

# %%
images, masks = load_dataset(dataset_path)
print(f"Images: {len(images)}")
print(f"Masks: {len(masks)}")
# Out:
# Images: 50
# Masks: 50

# %%
for x, y in zip(images, masks):
  print(x, y)
# Out:
# /content/drive/MyDrive/Colab Notebooks/data/images/1.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/1.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/10.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/10.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/11.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/11.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/12.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/12.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/13.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/13.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/14.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/14.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/15.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/15.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/16.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/16.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/17.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/17.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/18.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/18.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/19.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/19.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/2.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/2.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/45.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/45.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/46.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/46.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/47.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/47.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/48.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/48.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/49.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/49.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/5.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/5.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/50.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/50.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/6.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/6.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/7.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/7.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/8.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/8.jpg
# /content/drive/MyDrive/Colab Notebooks/data/images/9.jpg /content/drive/MyDrive/Colab Notebooks/data/masks/9.jpg

# %% [markdown]
# ### **Visualize the images and masks**

# %%
pip install imshowtools
# Out:
# Collecting imshowtools
#   Downloading imshowtools-0.6.5-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imshowtools) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imshowtools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imshowtools) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imshowtools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imshowtools) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imshowtools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imshowtools) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imshowtools) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imshowtools) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imshowtools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->imshowtools) (1.16.0)
# Downloading imshowtools-0.6.5-py3-none-any.whl (7.4 kB)
# Installing collected packages: imshowtools
# Successfully installed imshowtools-0.6.5

# %%
from imshowtools import imshow

cat = []

for x,y in zip(images[:6], masks[:6]):
  x = cv2.imread(x, cv2.IMREAD_COLOR)
  x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
  y = cv2.imread(y, cv2.IMREAD_COLOR)
  z = np.concatenate((x, y), axis=0)
  cat.append(z)

imshow(*cat, size=(20, 10), columns=3)

# %% [markdown]
# ### **Dataset split**

# %%
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = split_dataset(images, masks, split=0.2)

# %%
print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")
print(f"Test: {len(test_x)} - {len(test_y)}")
# Out:
# Train: 30 - 30
# Valid: 10 - 10
# Test: 10 - 10

# %% [markdown]
# ### **Saving the dataset**
#
# #### ***1. Creating the folders***

# %%
save_dir = os.path.join("/content/drive/MyDrive/Colab Notebooks/data/dataset", "non-aug")
for item in ["train", "valid", "test"]:
  create_dir(os.path.join(save_dir, item, "images"))
  create_dir(os.path.join(save_dir, item, "masks"))

# %% [markdown]
# #### ***2. Saving the traing dataset***

# %%
save_dataset(train_x, train_y, save_dir=os.path.join(save_dir, "train"))
# Out:
# 100%|██████████| 30/30 [00:23<00:00,  1.27it/s]

# %% [markdown]
# #### ***3. Saving the validation dataset***

# %%
save_dataset(valid_x, valid_y, save_dir=os.path.join(save_dir, "valid"))
# Out:
# 100%|██████████| 10/10 [00:07<00:00,  1.27it/s]

# %% [markdown]
# #### ***4. Saving the testing dataset***

# %%
save_dataset(test_x, test_y, save_dir=os.path.join(save_dir, "test"))
# Out:
# 100%|██████████| 10/10 [00:05<00:00,  2.00it/s]
